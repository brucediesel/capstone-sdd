# %% [markdown]
# # F1 — Week 11 Performance Review
#
# **Objective**: Review the optimisation performance of F1 across all 11 submission rounds and propose strategy for next submission.
#
# **Function**: F1 (2D input, 1D output, maximisation)
#
# **Week 10 Strategy**: SFGP Matérn-2.5 ARD + qLogNEI q=4 with log transform + distance-based selection + 10,000 Sobol seeds + interior penalty (shallow) + aggressive exploitation.
#
# This notebook loads the Week 11 data, visualises convergence (log scale) and input-space coverage, evaluates performance, and proposes strategy improvements.

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
import math

# ── Function Configuration ──
FUNC_NUM = 1
N_DIMS = 2
N_INITIAL = 10
WEEK = 11
USE_LOG_SCALE = True  # F1 uses log scale for convergence
DATA_DIR = '../../data/f1/'

# %% [markdown]
# ## Step 1 — Load Data

# %%
# Load Week 11 data
inputs = np.load(f'{DATA_DIR}updated_inputs - Week {WEEK}.npy')
outputs = np.load(f'{DATA_DIR}updated_outputs - Week {WEEK}.npy')

n_total = len(outputs)
n_submissions = n_total - N_INITIAL

print(f'F{FUNC_NUM} — Week {WEEK} Data Summary')
print(f'  Input dimensions:  {N_DIMS}')
print(f'  Total samples:     {n_total}')
print(f'  Initial samples:   {N_INITIAL}')
print(f'  Submissions:       {n_submissions}')
print(f'  Input shape:       {inputs.shape}')
print(f'  Output shape:      {outputs.shape}')
print(f'  Best output:       {outputs.max():.6g}')
print(f'  Worst output:      {outputs.min():.6g}')
print()

# Display data table
print('Sample | ' + ' | '.join([f'x{j+1:d}' for j in range(N_DIMS)]) + ' | y')
print('-' * (10 + N_DIMS * 12 + 15))
for i in range(n_total):
    label = 'init' if i < N_INITIAL else f'wk{i - N_INITIAL + 3}'
    row = f'{i+1:>4d}({label:>4s}) | '
    row += ' | '.join([f'{inputs[i, j]:.6f}' for j in range(N_DIMS)])
    row += f' | {outputs[i]:.6g}'
    print(row)
# Out:
# F1 — Week 11 Data Summary
#   Input dimensions:  2
#   Total samples:     21
#   Initial samples:   10
#   Submissions:       11
#   Input shape:       (21, 2)
#   Output shape:      (21,)
#   Best output:       7.71088e-16
#   Worst output:      -0.00360606
#
# Sample | x1 | x2 | y
# -------------------------------------------------
#    1(init) | 0.319404 | 0.762959 | 1.32268e-79
#    2(init) | 0.574329 | 0.879898 | 1.03308e-46
#    3(init) | 0.731024 | 0.733000 | 7.71088e-16
#    4(init) | 0.840353 | 0.264732 | 3.34177e-124
#    5(init) | 0.650114 | 0.681526 | -0.00360606
#    6(init) | 0.410437 | 0.147554 | -2.15925e-54
#    7(init) | 0.312691 | 0.078723 | -2.08909e-91
#    8(init) | 0.683418 | 0.861057 | 2.535e-40
#    9(init) | 0.082507 | 0.403488 | 3.60677e-81
#   10(init) | 0.883890 | 0.582254 | 6.22986e-48
#   11( wk3) | 0.448979 | 0.142857 | 2.31408e-56
#   12( wk4) | 0.708964 | 0.494269 | -1.15988e-17
#   13( wk5) | 0.986481 | 0.986619 | 4.9777e-180
#   14( wk6) | 0.060194 | 0.333985 | 2.84272e-97
#   15( wk7) | 0.740501 | 0.838613 | 1.01873e-40
#   16( wk8) | 0.003918 | 0.999460 | 0
#   17( wk9) | 0.004402 | 0.000330 | 1.87428e-245
#   18(wk10) | 0.432767 | 0.484184 | -0.00109123
#   19(wk11) | 0.797902 | 0.037269 | 6.93628e-202
#   20(wk12) | 0.728938 | 0.779820 | -1.54765e-23
#   21(wk13) | 0.999999 | 0.371457 | 1.35284e-142

# %% [markdown]
# ## Step 2 — Convergence Plot
#
# Running best (maximum) objective value over all samples. F1 uses **log scale** with negative outputs zeroed before log calculation.

# %%
# Compute running best (maximisation)
running_best = np.maximum.accumulate(outputs)

fig, ax = plt.subplots(figsize=(10, 5))

x_all = np.arange(1, n_total + 1)

if USE_LOG_SCALE:
    # Zero negative values, then apply log (avoid log(0) with small epsilon)
    plot_vals = np.where(running_best > 0, running_best, 0)
    # Replace zeros with a small value for log scale display
    plot_vals_log = np.where(plot_vals > 0, plot_vals, 1e-300)
    ax.set_yscale('log')
    ax.set_ylabel('Running Best (log scale, negatives zeroed)')
    plot_vals = plot_vals_log
else:
    plot_vals = running_best
    ax.set_ylabel('Running Best')

# Plot initial samples in blue
ax.plot(x_all[:N_INITIAL], plot_vals[:N_INITIAL], 'o-', color='tab:blue',
        label='Initial samples', markersize=5)

# Plot submissions in orange
ax.plot(x_all[N_INITIAL-1:], plot_vals[N_INITIAL-1:], 'o-', color='tab:orange',
        label='Submissions', markersize=5)

# Vertical separator
ax.axvline(x=N_INITIAL + 0.5, color='grey', linestyle='--', alpha=0.7,
           label='Initial / Submission boundary')

ax.set_xlabel('Sample Number')
ax.set_title(f'F{FUNC_NUM} — Convergence Plot (Week {WEEK}, Log Scale)')
ax.legend()
ax.grid(True, alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Step 3 — 2D Pair Plots
#
# Scatter plots of each unique pair of input dimensions showing spatial coverage. Initial samples in **blue** (unmarked), submission samples in **orange** (numbered by submission week).

# %%
# Generate all unique pairs of input dimensions
pairs = list(combinations(range(N_DIMS), 2))
n_pairs = len(pairs)

# Find the overall best output
best_idx = np.argmax(outputs)

if n_pairs == 0:
    print('Only 1 dimension — no pair plots to display.')
else:
    # Grid layout
    n_cols = min(n_pairs, 3) if n_pairs <= 6 else min(n_pairs, 5) if n_pairs <= 15 else 7
    n_rows = math.ceil(n_pairs / n_cols)
    fig_width = n_cols * 4
    fig_height = n_rows * 3.5

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(fig_width, fig_height),
                             squeeze=False)

    for idx, (di, dj) in enumerate(pairs):
        row, col = divmod(idx, n_cols)
        ax = axes[row][col]

        # Initial samples — blue, unmarked
        ax.scatter(inputs[:N_INITIAL, di], inputs[:N_INITIAL, dj],
                   c='tab:blue', marker='o', s=40, alpha=0.7, label='Initial')

        # Submission samples — orange, numbered by week
        for k in range(N_INITIAL, n_total):
            week_num = k - N_INITIAL + 3  # Weeks start at 3
            ax.scatter(inputs[k, di], inputs[k, dj],
                       c='tab:orange', marker='o', s=40, alpha=0.7)
            ax.annotate(str(week_num), (inputs[k, di], inputs[k, dj]),
                        textcoords='offset points', xytext=(4, 4),
                        fontsize=7, color='tab:orange', fontweight='bold')

        # Best output — red star
        ax.scatter(inputs[best_idx, di], inputs[best_idx, dj],
                   c='red', marker='*', s=200, zorder=5, label='Best')

        ax.set_xlabel(f'x{di+1}')
        ax.set_ylabel(f'x{dj+1}')
        ax.set_xlim(-0.05, 1.05)
        ax.set_ylim(-0.05, 1.05)
        ax.set_title(f'x{di+1} vs x{dj+1}')
        ax.grid(True, alpha=0.3)

    # Add legend to first subplot
    from matplotlib.patches import Patch
    from matplotlib.lines import Line2D
    legend_elements = [Patch(facecolor='tab:blue', label='Initial'),
                       Patch(facecolor='tab:orange', label='Submissions'),
                       Line2D([0], [0], marker='*', color='w', markerfacecolor='red',
                              markersize=15, label='Best')]
    axes[0][0].legend(handles=legend_elements, loc='upper right', fontsize=7)

    # Hide empty subplots
    for idx in range(n_pairs, n_rows * n_cols):
        row, col = divmod(idx, n_cols)
        axes[row][col].set_visible(False)

    fig.suptitle(f'F{FUNC_NUM} — Input Space Coverage (Week {WEEK})', fontsize=14)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ## Step 4 — Performance Evaluation
#
# ### Week 10 Strategy
#
# - **Surrogate**: SFGP Matérn-2.5 ARD with log transform
# - **Acquisition**: qLogNEI q=4 + interior penalty (shallow) + aggressive exploitation
# - **Key changes**: Switched from Hurdle Model to GP, added Sobol seeds (10k), distance-based selection
#
# ### Performance Summary

# %%
# Performance metrics
running_best = np.maximum.accumulate(outputs)
init_best = running_best[N_INITIAL - 1]

# Count improvements and detect stalling
improvements = 0
consec_no_improve = 0
max_consec_no_improve = 0
prev_best = init_best

for j in range(N_INITIAL, n_total):
    if running_best[j] > prev_best:
        improvements += 1
        consec_no_improve = 0
    else:
        consec_no_improve += 1
        max_consec_no_improve = max(max_consec_no_improve, consec_no_improve)
    prev_best = running_best[j]

stalling = max_consec_no_improve >= 3

print(f'Best value (initial):     {init_best:.6g}')
print(f'Best value (final):       {running_best[-1]:.6g}')
print(f'Improvements:             {improvements}/{n_submissions}')
print(f'Max consecutive no-improve: {max_consec_no_improve}')
print(f'Stalling (≥3 consec):     {stalling}')
print()

# Per-submission performance
print('Week | Output         | Best-so-far    | Improved?')
print('-' * 55)
for j in range(N_INITIAL, n_total):
    week_num = j - N_INITIAL + 3
    improved = '✓' if (j == N_INITIAL and outputs[j] > init_best) or \
               (j > N_INITIAL and running_best[j] > running_best[j-1]) else '✗'
    print(f'  {week_num:>2d} | {outputs[j]:>14.6g} | {running_best[j]:>14.6g} | {improved}')
# Out:
# Best value (initial):     7.71088e-16
# Best value (final):       7.71088e-16
# Improvements:             0/11
# Max consecutive no-improve: 11
# Stalling (≥3 consec):     True
#
# Week | Output         | Best-so-far    | Improved?
# -------------------------------------------------------
#    3 |    2.31408e-56 |    7.71088e-16 | ✗
#    4 |   -1.15988e-17 |    7.71088e-16 | ✗
#    5 |    4.9777e-180 |    7.71088e-16 | ✗
#    6 |    2.84272e-97 |    7.71088e-16 | ✗
#    7 |    1.01873e-40 |    7.71088e-16 | ✗
#    8 |              0 |    7.71088e-16 | ✗
#    9 |   1.87428e-245 |    7.71088e-16 | ✗
#   10 |    -0.00109123 |    7.71088e-16 | ✗
#   11 |   6.93628e-202 |    7.71088e-16 | ✗
#   12 |   -1.54765e-23 |    7.71088e-16 | ✗
#   13 |   1.35284e-142 |    7.71088e-16 | ✗

# %% [markdown]
# ## Step 5 — Strategy Proposals for Next Submission
#
# Review the performance metrics and convergence plot above. Key considerations for F1:
#
# 1. **F1 has been the most challenging function** — historically 0/10 improvements through week 10. Check if the week 10 strategy switch (Hurdle → SFGP + qLogNEI) produced improvement in week 11.
#
# 2. **If week 11 improved**: The SFGP + qLogNEI strategy is working. Continue with:
#    - Same surrogate (SFGP Matérn-2.5 ARD + log transform)
#    - Increase exploitation by reducing q from 4 to 2
#    - Tighten distance-based selection to focus near the improving region
#
# 3. **If week 11 did NOT improve**: The log-transformed GP may still be struggling with F1's extremely localised optima. Consider:
#    - **Increase Sobol seeds to 20,000** for broader acquisition coverage
#    - **Try Matérn-1.5 kernel** (rougher, may capture sharp peaks better)
#    - **Switch to pure exploration** with UCB κ=2.0 to escape the current search region entirely
#    - **Consider Latin Hypercube sampling** as a fallback — place points in uncovered regions of [0,1]²
#    - **Remove interior penalty** if it is constraining search away from edges where the optimum might be
#
# 4. **General**: F1 outputs span many orders of magnitude. Ensure the log transform epsilon is appropriate for the output scale observed in week 11 data.

# %% [markdown]
# ## ARD Feature Relevance Analysis
#
# Automatic Relevance Determination (ARD) assigns a separate lengthscale parameter to each input dimension in the GP kernel. **Smaller lengthscale → the model is more sensitive to that dimension → higher relevance.**
#
# Below we fit a SingleTaskGP with a Matérn-2.5 ARD kernel on the current data, extract the per-dimension lengthscales, and visualise the normalised relevance scores. The output transform matches the optimisation notebook: Standardize(m=1).

# %%
import torch
import gpytorch
from botorch.models import SingleTaskGP
from botorch.models.transforms.outcome import Standardize
from botorch.fit import fit_gpytorch_mll
from gpytorch.mlls import ExactMarginalLogLikelihood
from gpytorch.kernels import MaternKernel, ScaleKernel
from gpytorch.priors import GammaPrior
from gpytorch.constraints import GreaterThan

# Prepare training data
X_train = torch.tensor(inputs, dtype=torch.float64)
Y_train = torch.tensor(outputs, dtype=torch.float64).unsqueeze(-1)

# Fit SingleTaskGP with Matérn-2.5 ARD kernel
covar_module = ScaleKernel(
    MaternKernel(nu=2.5, ard_num_dims=N_DIMS, lengthscale_prior=GammaPrior(3.0, 6.0)),
    outputscale_prior=GammaPrior(2.0, 0.15),
)
model = SingleTaskGP(X_train, Y_train, covar_module=covar_module, outcome_transform=Standardize(m=1))
model.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-4))
mll = ExactMarginalLogLikelihood(model.likelihood, model)
fit_gpytorch_mll(mll)

# Extract ARD lengthscales
lengthscales = model.covar_module.base_kernel.lengthscale.detach().squeeze().numpy()
dim_names = ["x1", "x2"]

print(f"F{FUNC_NUM}: ARD Lengthscales (Matérn-2.5 kernel)")
print(f"{'Dimension':<15} {'Lengthscale':>12}")
print("-" * 28)
for name, ls in zip(dim_names, lengthscales):
    print(f"{name:<15} {ls:>12.6f}")
# Out:
# ---------------------------------------------------------------------------
# InputDataError                            Traceback (most recent call last)
# Cell In[26], line 19
#      14 # Fit SingleTaskGP with Matérn-2.5 ARD kernel
#      15 covar_module = ScaleKernel(
#      16     MaternKernel(nu=2.5, ard_num_dims=N_DIMS, lengthscale_prior=GammaPrior(3.0, 6.0)),
#      17     outputscale_prior=GammaPrior(2.0, 0.15),
#      18 )
# ---> 19 model = SingleTaskGP(X_train, Y_train, covar_module=covar_module)
#      20 model.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-4))
#      21 mll = ExactMarginalLogLikelihood(model.likelihood, model)
#
# File ~/.pyenv/versions/sdd-dev/lib/python3.14/site-packages/botorch/models/gp_regression.py:164, in SingleTaskGP.__init__(self, train_X, train_Y, train_Yvar, likelihood, covar_module, mean_module, outcome_transform, input_transform)
#     162 self._validate_tensor_args(X=transformed_X, Y=train_Y, Yvar=train_Yvar)
#     163 ignore_X_dims = getattr(self, "_ignore_X_dims_scaling_check", None)
# --> 164 validate_input_scaling(
#     165     train_X=transformed_X,
#     166     train_Y=train_Y,
#     167     train_Yvar=train_Yvar,
#     168     ignore_X_dims=ignore_X_dims,
#     169     check_nans_only=covar_module is not None,
#     170 )
#     171 self._set_dimensions(train_X=train_X, train_Y=train_Y)
#     172 train_X, train_Y, train_Yvar = self._transform_tensor_args(
#     173     X=train_X, Y=train_Y, Yvar=train_Yvar
#     174 )
#
# File ~/.pyenv/versions/sdd-dev/lib/python3.14/site-packages/botorch/models/utils/assorted.py:265, in validate_input_scaling(train_X, train_Y, train_Yvar, raise_on_fail, ignore_X_dims, check_nans_only)
#     263     return
#     264 check_no_nans(train_X)
# --> 265 check_no_nans(train_Y)
#     266 if train_Yvar is not None:
#     267     check_no_nans(train_Yvar)
#
# File ~/.pyenv/versions/sdd-dev/lib/python3.14/site-packages/botorch/models/utils/assorted.py:133, in check_no_nans(Z)
#     125 r"""Check that tensor does not contain NaN values.
#     126
#     127 Raises an InputDataError if `Z` contains NaN values.
#    (...)    130     Z: The input tensor.
#     131 """
#     132 if torch.any(torch.isnan(Z)).item():
# --> 133     raise InputDataError("Input data contains NaN values.")
#
# InputDataError: Input data contains NaN values.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute normalised relevance: relevance = 1/lengthscale, then normalise to sum to 1
inv_lengthscales = 1.0 / lengthscales
relevance = inv_lengthscales / inv_lengthscales.sum()

# Plot horizontal bar chart
fig, ax = plt.subplots(figsize=(8, max(3, len(dim_names) * 0.6)))
y_pos = np.arange(len(dim_names))
bars = ax.barh(y_pos, relevance, color="steelblue", edgecolor="black", height=0.5)

# Annotate bars with percentage
for bar, rel in zip(bars, relevance):
    ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height() / 2,
            f"{rel:.1%}", va="center", fontsize=11)

ax.set_yticks(y_pos)
ax.set_yticklabels(dim_names, fontsize=11)
ax.set_xlabel("Normalised Relevance", fontsize=12)
ax.set_title(f"F{FUNC_NUM}: ARD Feature Relevance (Matérn-2.5 kernel)", fontsize=13, fontweight="bold")
ax.set_xlim(0, min(1.0, relevance.max() * 1.3))
ax.invert_yaxis()
plt.tight_layout()
plt.show()
